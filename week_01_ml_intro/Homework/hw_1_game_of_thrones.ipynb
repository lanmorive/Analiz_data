# %% [markdown]
# ![dls.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h1 style="text-align: center;"><b>Домашнее задание. Библиотека sklearn и классификация с помощью KNN</b></h1>

# %% [markdown]
# ## Описание домашнего задания

# %% [markdown]
# ![martin.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# В данном задании вы будете работать с датасетом о персонажах из вселенной Игры Престолов [A Wiki of Ice and Fire](http://awoiaf.westeros.org/). Вам предстоит предсказать, кто из персонажей умрет, а кто останется вживых.

# %% [markdown]
# Описание данных:
#
# * **name**: Имя персонажа
#
# * **Title**: Социальный статус или знатность
#
# * **House**: Дом, к которому принадлежит персонаж
#
# * **Culture**: Социальная группа, к которой принадлежит персонаж
#
# * **book1/2/3/4/5**: Появление персонажа в книге
#
# * **Is noble**: Знатность персонажа, основанное на титуле
#
# * **Age**: Отсчет времени: 305 AC
#
# * **male**: Мужчина или женщина
#
# * **dateOfBirth**: дата рождения
#
# * **Spouse**: Имя супруги\а персонажа
#
# * **Father**: Имя отца персонажа
#
# * **Mother**: Имя матери персонажа
#
# * **Heir**: Имя наследника персонажа
#
# * **Is married**: Represents whether the character is married
#
# * **Is spouse alive**: Represents whether character's spouse is alive
#
# * **Is mother alive:** Жива ли мать персонажа
#
# * **Is heir alive:** Жив ли наследник персонажа
#
# * **Is father alive:** Указывает, жив ли отец персонажа
#
# * **Number dead relations:** Количество умерших персонажей, с которыми персонаж связан
#
# * **Popularity score:** Количество внутренних входящих и исходящих ссылок на страницу персонажей в вики http://awoiaf.westeros.org
#
# Целевая переменная:
# * **isAlive**: жив ли персонаж в книге

# %% [markdown]
# Оценивание:
#
# Баллы считаются следующим образом:
#
# 1) $1.00 \geqslant score \geqslant 0.65$ --- 5 баллов
#
# 2) $0.65 > score \geqslant 0.50$ --- 4 балла
#
# 3) $0.50 > score \geqslant 0.45$ --- 3 балла
#
# 4) $0.45 > score \geqslant 0.40$ --- 2 балла
#
# 5) $0.40 > score \geqslant 0.35$ --- 1 балл
#
# 6) $0.35 > score$ --- 0 баллов

# %% [markdown]
# ## Часть 1. Анализ и предобработка данных

# %% [markdown]
# Здесь вам необходимо сделать все шаги, которые обсуждались в первой части семинара.
# * Предобработка данных
#   * Обработка пропущенных данных
#   * Создание новых признаков
#   * Удаление ненужных столбцов
# * Анализ данных
#   * Анализ целевой переменной
#   * Анализ признаков
#   * Анализ влияния признаков на целевую переменную
# * Подготовка данных для обучения модели

# %% [markdown]
# Загружаем датасет

# %%
# !gdown 1h99toeF7lZ2I3iJwehgKO-QQmDaOe_O3 # test dataset
# !gdown 1XL0VTygpZj-ZAuTNRBgApZTPQyNDnT-v # train dataset
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1h99toeF7lZ2I3iJwehgKO-QQmDaOe_O3
# To: /content/game_of_thrones_test.csv
# 100% 37.3k/37.3k [00:00<00:00, 52.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1XL0VTygpZj-ZAuTNRBgApZTPQyNDnT-v
# To: /content/game_of_thrones_train.csv
# 100% 138k/138k [00:00<00:00, 21.0MB/s]

# %% [markdown]
# **Задание 1.1.** Импортируйте библиотеки pandas, matplotlib, seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# **Задание 1.2.** Загрузите датасет в Pandas DataFrame при помощи функции `read_csv`. Вместо дефолтных наименований строк `0,1,...`, при помощи параметра `index_col`, сделайте значения колонки `S.No` наименованиями строк:

# %%
data = pd.read_csv(r'/content/game_of_thrones_train.csv',index_col = 'S.No')

# %% [markdown]
# Посмотрите, какие типы данных представлены в нашем датасете

# %% [markdown]
# Знакомый нам метод describe() возвращает различную информацию для столбцов с числовыми типами данных, и с типами данных *object*
#
# Давайте посмотрим на вывод для типа данных *object*. Для этого:
# - сначала применим метод describe(). Укажем в качестве аргумента тип данных столбцов, статистику по которым мы хотим посмотреть (см. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)
# - для удобства восприятия транспонируем таблицу

# %%
data.describe(include = 'object').T
# Out:
#         count unique                  top freq
# name     1557   1557   Melara Hetherspoon    1
# title     717    195                  Ser  306
# culture   488     51             Northmen   94
# mother     18     16   Rhaenyra Targaryen    2
# father     22     19     Daemon Targaryen    2
# heir       21     20  Jaehaerys Targaryen    2
# house    1176    315           House Frey   89
# spouse    200    186          Walder Frey    6

# %% [markdown]
# Теперь давайте посмотрим на столбцы с числовыми типами данных. Дополните код ниже. Для удобства восприятия мы транспонировали таблицу и ограничили вывод тремя столбцами - количество строк без NaN, максимальное и минимальное значение (о кастомизации вариантах вывода describe() вы можете почитать в документации по ссылке выше).

# %%
data.describe().T[['count', 'min', 'max']]
# Out:
#                    count   min    max
# male              1557.0   0.0    1.0
# dateOfBirth        279.0 -25.0  299.0
# book1             1557.0   0.0    1.0
# book2             1557.0   0.0    1.0
# book3             1557.0   0.0    1.0
# book4             1557.0   0.0    1.0
# book5             1557.0   0.0    1.0
# isAliveMother       18.0   0.0    1.0
# isAliveFather       22.0   0.0    1.0
# isAliveHeir         21.0   0.0    1.0
# isAliveSpouse      200.0   0.0    1.0
# isMarried         1557.0   0.0    1.0
# isNoble           1557.0   0.0    1.0
# age                279.0   0.0  100.0
# numDeadRelations  1557.0   0.0   15.0
# popularity        1557.0   0.0    1.0
# isAlive           1557.0   0.0    1.0

# %% [markdown]
# Так мы проверим, есть ли в данных неадекватнные значения.   Большинство числовых столбцов - это числа от 0 до 1. Отрицательные значения `dateOfBirth` не являются ошибкой. Значения age и `numDeadRelations` также выглядят адекватными. Можно переходить к дальнейшим шагам анализа (анонс - а в тестовых данных нас будет ждать сюрприз).

# %% [markdown]
# **Задание 1.3.** Предобработка (очистка) данных.
#
# В нашем домашнем задании все пропуски в данных (missing values) уже закодированы как NaN. Проанализируйте, в каких колонках и как часто встречаются NaN значения. Далее вам надо будет принять решение, как их обрабатывать.

# %%
data.isna().sum()/len(data) * 100
# Out:
# name                 0.000000
# title               53.949904
# male                 0.000000
# culture             68.657675
# dateOfBirth         82.080925
# mother              98.843931
# father              98.587026
# heir                98.651252
# house               24.470135
# spouse              87.154785
# book1                0.000000
# book2                0.000000
# book3                0.000000
# book4                0.000000
# book5                0.000000
# isAliveMother       98.843931
# isAliveFather       98.587026
# isAliveHeir         98.651252
# isAliveSpouse       87.154785
# isMarried            0.000000
# isNoble              0.000000
# age                 82.080925
# numDeadRelations     0.000000
# popularity           0.000000
# isAlive              0.000000
# dtype: float64

# %% [markdown]
# В этом задании удалять строки с NaN (dropna) мы не будем по следующим причинам:
# - в обучающем датасете много признаков с большим количество пропусков. Если удалять все строки с NaN, то размер выборки сильно уменьшится. Мы потеряем много данных, которые можно было бы использовать для построения более точной модели.
# - тестовом датасете также много признаков с NaN (вы можете в этом убедиться, если скачаете датасет и совершите с ним те же действия, что выше проделали с обучаюшим датасетом). Поэтому нам все-равно придется придумать способ кодировать NaN, чтобы модель делала прогнозы для всех персонажей из тестового датасета. Для этого нам потребуется сохранять, а не удалять данные в обучающем датасете.

# %% [markdown]
# Как вы могли заметить, в наших данных очень много пропущенных значений, причём в некоторых случая пропущена **большая** часть значений. Поэтому заполнять по умолчанию медианой/средним/модой в данном случае - не самый лучший способ (однако, это довольно часто используемый метод заполнения, который может пригодиться вам в будущем)
#
# Ниже мы посмотрим, как можно работать с признаками с большим количеством пропущенных значений.

# %% [markdown]
# **Задание 1.4.** Числовые признаки
#
# У нас есть **признак popularity**. Постройте гистограмму распределения данного признака с количеством интервалов (bins), равным 50 (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html)

# %%
data['popularity'].hist(bins = 50)
# Out:
# <Axes: >

# %% [markdown]
# Распределение сильно несимметрично. Можно преобразовать данный признак, например, по формуле `np.log10(data["popularity"]*M+1)` (добавляем 1 ради логарифма, так как для нектоторых персонажей `popularity==0`). В качестве M можно попробовать, например, M=100 или другое число.
#
# При желании для `popularity` вы можете использовать свой способ шкалирования признаков с несимметричным распределением.

# %%
M = 100

data['log_pop'] = np.log10(data["popularity"]*M+1)

data['log_pop'].hist(bins = 50);

# %% [markdown]
# В качестве альтернативного подхода вы можете попробовать дискретизацию признака popularity на основе квантилей (quantile binning), используя функцию qcut() (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html). В этом случае вы преобразуете числовой признак popularity в категориальный, для которого в дальнейшем надо будет применить one-hot кодирование.

# %% [markdown]
# Теперь давайте обработаем **признак numDeadRelations**.
# Посмотрите на частотное распределение этого признака. Лишь для малого числа персонажей `numDeadRelations>0`.
#
# Создайте признак `boolDeadRelations`. Давайте упростим признак `numDeadRelations`, и просто поделим людей на тех, у кого были хоть какие то отношения с мертвыми персонажами, т.е. `numDeadRelations > 0`, и те, у которых не было, т.е. `numDeadRelations = 0`.

# %%
data['boolDeadRelations'] = (data['numDeadRelations'] > 0).astype(int)

# %% [markdown]
# Наконец, давайте посмотрим на **признак age**. В нем очень много пропущенных значений. Для того, чтобы использовать в модели информацию о возрасте персонажа, мы создадим два новых признака: `age_value` и `age_no_data`
#
# - Там где возраст указан, age_value принимает значение `age`, а `age_no_data` - значение 0.
# - Там где возраст не указан, `age_value` принимает значение 0, а `age_no_data` - значение 1.
#
# Фактически, в переменной `age` мы заменяем NaN на 0, но одновременно добавляем в модель еще один бинарный признак `age_no_data`, несущий информацию о том, у каких персонажей не был указан возраст:

# %%
data['age_value'] = data['age'].fillna(0)
data['age_no_data'] = [1 if np.isnan(x) else 0 for x in data['age']]

# %% [markdown]
# Этот способ чем-то похож на работу с категориальной переменными с пропущенными значениями, когда мы добавляем еще одну категорию no_data и заменяем NaN на значение этой категории.

# %% [markdown]
# Если вы заходите похожим образом образом обработать признак `dateOfBirth`, **обратите внимание**, что у одних и тех же персонажей не указан и возраст, и год рождения.
# То есть созданные признаки `age_no_data` и `dateOfBirth_no_data` будут полностью совпадать, и в модель надо будет включать только один из признаков: или `age_no_data`, или `dateOfBirth_no_data`.

# %% [markdown]
# **Задание 1.5.** Категориальные признаки с большим количеством категорий

# %% [markdown]
# **Признак culture** содержит информацию о принадлежности к одному из народов во вселенной Игры Престолов.
#
# Давайте посмотрим, какие значения принимает данный признак. По умолчанию метод `value_counts()` игнорирует пропуски в данных, поэтому используем этот метод с параметром **dropna** со значением **False** (см. https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.value_counts.html)

# %%
data['culture'].value_counts(dropna = False)
# Out:
# culture
# NaN                        1069
# Northmen                     94
# Ironborn                     91
# Free Folk                    45
# Braavosi                     39
# Valyrian                     28
# Ghiscari                     17
# Dornish                      17
# Dothraki                     17
# Reach                        13
# Vale mountain clans          12
# Rivermen                     10
# Valemen                      10
# northmen                      9
# Westerman                     8
# Free folk                     7
# Tyroshi                       6
# Qartheen                      5
# Stormlands                    4
# Summer Isles                  4
# Astapori                      4
# Westeros                      3
# Dornishmen                    3
# Ironmen                       3
# Northern mountain clans       3
# Westermen                     3
# Lysene                        2
# westermen                     2
# Meereenese                    2
# Myrish                        2
# Crannogmen                    2
# Sistermen                     2
# First Men                     2
# Lhazarene                     1
# Norvoshi                      1
# Qohor                         1
# Braavos                       1
# Ghiscaricari                  1
# ironborn                      1
# Andal                         1
# Lyseni                        1
# Qarth                         1
# Andals                        1
# Lhazareen                     1
# Vale                          1
# Wildling                      1
# Dorne                         1
# Pentoshi                      1
# free folk                     1
# Summer Islander               1
# Westerlands                   1
# Summer Islands                1
# Name: count, dtype: int64

# %% [markdown]
# Из полученного частотного распределения видно, что для большого числа персонажей значения данного признака не указаны. Также есть много редких значений признака, которые в выборке повторяются один или несколько раз. Причина отчасти в том, что один и тот же народ упоминается в нашем датасете под разными названиями.
#
# Данную проблему мы попытаемся решить, сгруппировав народы в более крупные категории. Так мы одновременно решим проблему того, что один и тот же народ назван в выборке разными способами.
#
# Предоженный вариант группировки имеет определенную логику. Выделяются следующие группы:
# - старые нации, которые уже не сущевали как отдельные народы на момент повествования основной линии повествования романов, но отдельные потомки могли еще быть живы
# - народы, проживающие в королевствах континента Весторос (для каждого королевства - своя группа)
# - народы континента Эссос
# - прочие народы

# %%
cultures_grouped = {
    'Old Nations': ['valyrian', 'first men', 'andal', 'andals', 'rhoynar'],
    'the North': ['northmen', 'northern mountain clans', 'crannogmen'],
    'the Iron Islands': ['ironborn', 'ironborn', 'ironmen'],
    'the Mountain and the Vale': ['valemen', 'vale', 'vale mountain clans',
                              'sistermen'],
    'the Isles and Rivers': ['riverlands', 'rivermen'],
    'the Rock': ['westerman', 'westermen', 'westerlands'],
    'the Stormlands': ['stormlander', 'stormlands'],
    'the Reach': ['reach', 'reachmen', 'the reach'],
    'Dorne': ['dornish', 'dornishmen', 'dorne'],
    'Essos Nations': ['astapor', 'astapori', 'braavosi', 'braavos', 'tyroshi', 'lysene', 'lyseni',
                      'myrish', 'pentoshi', 'qartheen', 'qarth', 'dothraki',
                      'lhazarene', 'lhazareen','meereen', 'meereenese',
                      'norvoshi', 'qohor', 'summer isles', 'summer islands',
                      'summer islander', 'asshai', "asshai'i", 'norvos', 'ghiscari',
                      'ghiscaricari'],
    'Other Nations': ['ibbenese', 'westeros', 'free folk', 'wildling', 'wildlings', 'naathi']}

# %% [markdown]
# **Обратите внимание, что некоторые варианты названий народов встречаются только в тестовых данных, и не встречаются в обучающих данных.** Такая ситуация нередко случается на практике. Поэтому, после обработки обучающих данных и обучения модели важно задать для модели правило, как она должна обрабатывать "незнакомые" категории в категориальных признаках. Например, можно относить объекты с "незнакомой" категорией к некоторой существующей категории или указать формулу расчета для "незнакомой" категории.
#
# Предложенный вам словарь `cultures_grouped` составлен по всем значениям признака `culture`, встречающимся в тренировочном либо в тестовом датасете. Здесь важно, что все укрупненные категории (ключи/keys словаря `cultures_grouped`) представлены в обоих датасетах, а уникальные для тестового датасета названия народов - это отдельные названия народов внутри укрупненных категорий (значения/values словаря). Поэтому, когда вы будете работать с тестовыми - просто применяйте этот словарь без указания правила обработки "незнакомых" категорий.

# %% [markdown]
# Давайте приступим к кодировке значений признака culture.
# Для этого сначала инвертируем словарь *cultures_grouped*

# %%
cultures_grouped_inverted = {}

for k in cultures_grouped.keys():
  for v in cultures_grouped[k]:
      cultures_grouped_inverted.update({v:k})
# Out:
# {'valyrian': 'Old Nations',
#  'first men': 'Old Nations',
#  'andal': 'Old Nations',
#  'andals': 'Old Nations',
#  'rhoynar': 'Old Nations',
#  'northmen': 'the North',
#  'northern mountain clans': 'the North',
#  'crannogmen': 'the North',
#  'ironborn': 'the Iron Islands',
#  'ironmen': 'the Iron Islands',
#  'valemen': 'the Mountain and the Vale',
#  'vale': 'the Mountain and the Vale',
#  'vale mountain clans': 'the Mountain and the Vale',
#  'sistermen': 'the Mountain and the Vale',
#  'riverlands': 'the Isles and Rivers',
#  'rivermen': 'the Isles and Rivers',
#  'westerman': 'the Rock',
#  'westermen': 'the Rock',
#  'westerlands': 'the Rock',
#  'stormlander': 'the Stormlands',
#  'stormlands': 'the Stormlands',
#  'reach': 'the Reach',
#  'reachmen': 'the Reach',
#  'the reach': 'the Reach',
#  'dornish': 'Dorne',
#  'dornishmen': 'Dorne',
#  'dorne': 'Dorne',
#  'astapor': 'Essos Nations',
#  'astapori': 'Essos Nations',
#  'braavosi': 'Essos Nations',
#  'braavos': 'Essos Nations',
#  'tyroshi': 'Essos Nations',
#  'lysene': 'Essos Nations',
#  'lyseni': 'Essos Nations',
#  'myrish': 'Essos Nations',
#  'pentoshi': 'Essos Nations',
#  'qartheen': 'Essos Nations',
#  'qarth': 'Essos Nations',
#  'dothraki': 'Essos Nations',
#  'lhazarene': 'Essos Nations',
#  'lhazareen': 'Essos Nations',
#  'meereen': 'Essos Nations',
#  'meereenese': 'Essos Nations',
#  'norvoshi': 'Essos Nations',
#  'qohor': 'Essos Nations',
#  'summer isles': 'Essos Nations',
#  'summer islands': 'Essos Nations',
#  'summer islander': 'Essos Nations',
#  'asshai': 'Essos Nations',
#  "asshai'i": 'Essos Nations',
#  'norvos': 'Essos Nations',
#  'ghiscari': 'Essos Nations',
#  'ghiscaricari': 'Essos Nations',
#  'ibbenese': 'Other Nations',
#  'westeros': 'Other Nations',
#  'free folk': 'Other Nations',
#  'wildling': 'Other Nations',
#  'wildlings': 'Other Nations',
#  'naathi': 'Other Nations'}

# %% [markdown]
# Теперь создадим новый столбец с укрупненными значениями culture.
#
# Для этого будем использовать метод `map()` с инвертированным словарем в качестве аргумента (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.map.html)
#
# Обратите внимание, что в словаре названия народов указаны в нижнем регистре. А в датасете используется как нижний, так и верхний регистр. Поэтому перед применением метода `map()` переведем значения столбца culture в нижний регистр при помощи метода `str.lower()` (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.lower.html).

# %%
data['culture_grouped'] = data['culture'].str.lower().map(cultures_grouped_inverted)

# %% [markdown]
# Осталось заменить все NaN в созданном столбце на категорию `culture_no_data`:

# %%
data['culture_grouped'].fillna('culture_no_data',inplace= True)
# Out:
# /tmp/ipython-input-946795927.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['culture_grouped'].fillna('culture_no_data',inplace= True)

# %% [markdown]
# Распределение сгруппированной переменной выглядит гораздо лучше. Но по прежнему есть несколько слабо представленых групп.
#
# Дальнейшую работу с этим признаком проводите на свое усмотрение для повышения качества прогноза модели. Например, можно объединить несколько слабо представленных категорий в одну или применить другой подход.

# %% [markdown]
# **Задание 1.6.** Категориальные признаки в линейных моделях
#
# Для включения категориальных признаков в линейную модель их нужно преобразовать в числовые признаки.
#
# Если признак принимает одно из двух возможных значений (например, персонаж "появляется" или "не появляется" в 1-й книге), он напрямую кодируется в бинарный признак ("появляется" -> 1, "не появляется" -> 0). Если признак принимает больше двух значений, его можно преобразовать в несколько бинарных при помощи one-hot преобразования. В некоторых случаях бывает полезно объединить некоторые категории, как мы это поступили с признаком *culture*.
#
# Порядковых признаков у нас в задаче нет, поэтому рассматривать их здесь мы не будем.

# %% [markdown]
# Для того, чтобы найти все порядковые признаки, посмотрим на количество уникальных значений, которые встречаются в столбцах. Для столбцов с типом object количество уникальных значений мы выводили  при помощи метода `describe()` в задании 1.2.
#
# Чтобы посмотреть количество уникальных значений для всех столбцов, можно воспользоваться методом nunique() (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nunique.html)

# %%
# Количество уникальнх значений в каждом столбце
data.nunique()
# Out:
# name                 1557
# title                 195
# male                    2
# culture                51
# dateOfBirth           105
# mother                 16
# father                 19
# heir                   20
# house                 315
# spouse                186
# book1                   2
# book2                   2
# book3                   2
# book4                   2
# book5                   2
# isAliveMother           2
# isAliveFather           2
# isAliveHeir             2
# isAliveSpouse           2
# isMarried               2
# isNoble                 2
# age                    72
# numDeadRelations       14
# popularity            117
# isAlive                 2
# log_pop               117
# boolDeadRelations       2
# age_value              72
# age_no_data             2
# culture_grouped        12
# dtype: int64

# %%
# Для числовых столбцов можно вывести в одну таблицу более детальную статистику, объединив выводы describe() и nunique()
# Код ниже требуется дополнить по аналогии с заданием 1.2.
data.describe().T[['count', 'min', 'max']].assign(N_unique_values = data.nunique())
# Out:
#                     count   min         max  N_unique_values
# male               1557.0   0.0    1.000000                2
# dateOfBirth         279.0 -25.0  299.000000              105
# book1              1557.0   0.0    1.000000                2
# book2              1557.0   0.0    1.000000                2
# book3              1557.0   0.0    1.000000                2
# book4              1557.0   0.0    1.000000                2
# book5              1557.0   0.0    1.000000                2
# isAliveMother        18.0   0.0    1.000000                2
# isAliveFather        22.0   0.0    1.000000                2
# isAliveHeir          21.0   0.0    1.000000                2
# isAliveSpouse       200.0   0.0    1.000000                2
# isMarried          1557.0   0.0    1.000000                2
# isNoble            1557.0   0.0    1.000000                2
# age                 279.0   0.0  100.000000               72
# numDeadRelations   1557.0   0.0   15.000000               14
# popularity         1557.0   0.0    1.000000              117
# isAlive            1557.0   0.0    1.000000                2
# log_pop            1557.0   0.0    2.004321              117
# boolDeadRelations  1557.0   0.0    1.000000                2
# age_value          1557.0   0.0  100.000000               72
# age_no_data        1557.0   0.0    1.000000                2

# %% [markdown]
# Посмотрев на количество уникальных значений мы можем выделить категориальные признаки. Например, `popularity` принимает значения от 0 до 1, но это непрерывный числовой признак. Остальные признаки со значениями от 0 до 1 - принимают только два значения, то есть являются бинарными.
#
# Бинарные признаки без NaN полностью готовы для включения в модель. Некоторые бинарные признаки содержат пропуски, поэтому, если вы захотите включить их в модель, их потребуется обработать.

# %% [markdown]
# Для бинарных признаков их связь с зависимой переменной можно прикинуть по таблице корреляций. Для категориальных признаков с количеством значений больше двух (или с двумя значениями и NaN) можно сделать one-hot преобразования и посчитать корреряцию зависимой переменной с набором сгенерированных бинарных признаков.
# В качестве альтернативного подхода можно использовать сравнение средних значений зависимой переменной для разных категорий исследуемого признака. Чем сильнее различаются средние значения целевой переменной между категориями, тем вероятнее, что данный признак связан с зависимой переменной.

# %%
# попробуйте провести сравнение средних зависимой пременной isAlive для признака isAliveSpouse
# одним из приведенных ниже способов:

data.groupby('isAliveSpouse', dropna = False)['isAlive'].mean()
pd.pivot_table(data = data, values = 'isAlive', index = 'isAliveSpouse', aggfunc=['mean', 'count'], dropna=False)
# Out:
#                    mean   count
#                 isAlive isAlive
# isAliveSpouse
# 0.0            0.619048      42
# 1.0            0.753165     158
# NaN            0.786293    1357

# %% [markdown]
# **Задание 1.7.** Проанализируйте признаки.
#   * Обработайте категориальные признаки и переведите их в числа. Можете выбрать любой кодировщик. Не забудьте, что потом аналогичным образом вам надо будет преобразовывать тестовый датасет, используя тот же алгоритм кодирования признаков.
#   * Проанализируйте количественные признаки. Есть ли корреляция между признаками?

# %%
data.isna().sum()/len(data) * 100
# Out:
# name                  0.000000
# title                53.949904
# male                  0.000000
# culture              68.657675
# dateOfBirth          82.080925
# mother               98.843931
# father               98.587026
# heir                 98.651252
# house                24.470135
# spouse               87.154785
# book1                 0.000000
# book2                 0.000000
# book3                 0.000000
# book4                 0.000000
# book5                 0.000000
# isAliveMother        98.843931
# isAliveFather        98.587026
# isAliveHeir          98.651252
# isAliveSpouse        87.154785
# isMarried             0.000000
# isNoble               0.000000
# age                  82.080925
# numDeadRelations      0.000000
# popularity            0.000000
# isAlive               0.000000
# log_pop               0.000000
# boolDeadRelations     0.000000
# age_value             0.000000
# age_no_data           0.000000
# culture_grouped       0.000000
# dtype: float64

# %%
cols_to_drop = ['mother', 'father', 'heir', 'isAliveMother', 'isAliveFather', 'isAliveHeir']
data.drop(cols_to_drop, axis=1, inplace=True)

# %%
data['spouse'].fillna('Unknown', inplace=True)
data['isAliveSpouse'].fillna(-1, inplace=True)
# Out:
# /tmp/ipython-input-382230947.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['spouse'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-382230947.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['isAliveSpouse'].fillna(-1, inplace=True)

# %%
data['has_title'] = data['title'].notna().astype(int)
data['culture'].fillna('Unknown', inplace=True)
data['house'].fillna('Unknown House', inplace=True)
# Out:
# /tmp/ipython-input-3714980340.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['culture'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-3714980340.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['house'].fillna('Unknown House', inplace=True)

# %% [markdown]
# В столбцах heir, father, mother очень много пропусков, поэтому просто делитну их.

# %%
data.drop(['title','dateOfBirth','age','name','culture'],inplace= True,axis = 1)

# %%
top_houses = data['house'].value_counts().nlargest(20).index
data['house_compressed'] = data['house'].apply(lambda x: x if x in top_houses else 'Other House')

data.drop('house', axis=1, inplace=True)

# %%
top_spouses = data['spouse'].value_counts().nlargest(10).index
data['spouse_compressed'] = data['spouse'].apply(lambda x: x if x in top_spouses else 'Other Spouse')
data.drop('spouse', axis=1, inplace=True)

# %%
df_encoded = pd.get_dummies(data, drop_first=False,dtype=int)

# %% [markdown]
# **Задание 1.8.** Проанализируйте влияние признаков на целевую переменную.

# %%
sns.pairplot(data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(30, 20))
sns.heatmap(df_encoded.corr(), cmap='coolwarm', center=0)
plt.title("Тепловая карта корреляций признаков")
plt.show()

# %% [markdown]
# **Задание 1.9.** Создайте переменные `X`, которая будет хранить только значения признаков, которые вы отобрали для включения в модель, и `y`, которая будет хранить только значения целевой переменной.

# %%
X = df_encoded.drop('isAlive',axis = 1)
y = df_encoded['isAlive']

# %% [markdown]
# **Задание 1.10.** Разделите датасет обучащую и валидационные части (train и val) при помощи функции `train_test_split` (https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)

# %%
from sklearn.model_selection import train_test_split

# %%
# не забудьте в функции train_test_split задать параметр random_state,
# чтобы обеспечить повторяемость разбиения выборки на train и validation части.
# Это позволит сравнивать метрики моделей с различными методами подготовки признаков
X_train, X_val, y_train, y_val = train_test_split(X,y,stratify=y)

# %%
X_train
# Out:
#       male  book1  book2  book3  book4  book5  isAliveSpouse  isMarried  \
# S.No
# 959      1      1      0      1      1      1           -1.0          0
# 9        1      0      0      1      0      0           -1.0          0
# 444      1      0      0      1      1      0           -1.0          0
# 182      1      0      0      0      0      1           -1.0          0
# 215      0      0      1      0      0      0           -1.0          0
# ...    ...    ...    ...    ...    ...    ...            ...        ...
# 288      1      0      0      0      0      0           -1.0          0
# 518      1      0      0      0      0      0           -1.0          0
# 1258     0      0      1      1      1      1           -1.0          0
# 646      1      0      0      0      1      0           -1.0          0
# 599      0      0      0      1      1      0           -1.0          0
#
#       isNoble  numDeadRelations  ...  spouse_compressed_Amerei Frey  \
# S.No                             ...
# 959         1                 0  ...                              0
# 9           1                 0  ...                              0
# 444         0                 0  ...                              0
# 182         0                 0  ...                              0
# 215         0                 0  ...                              0
# ...       ...               ...  ...                            ...
# 288         0                 0  ...                              0
# 518         1                 0  ...                              0
# 1258        1                 0  ...                              0
# 646         1                 0  ...                              0
# 599         0                 0  ...                              0
#
#       spouse_compressed_Craster  spouse_compressed_Kiera of Tyrosh  \
# S.No
# 959                           0                                  0
# 9                             0                                  0
# 444                           0                                  0
# 182                           0                                  0
# 215                           0                                  0
# ...                         ...                                ...
# 288                           0                                  0
# 518                           0                                  0
# 1258                          0                                  0
# 646                           0                                  0
# 599                           0                                  0
#
#       spouse_compressed_Other Spouse  spouse_compressed_Rohanne Webber  \
# S.No
# 959                                0                                 0
# 9                                  0                                 0
# 444                                0                                 0
# 182                                0                                 0
# 215                                0                                 0
# ...                              ...                               ...
# 288                                0                                 0
# 518                                0                                 0
# 1258                               0                                 0
# 646                                0                                 0
# 599                                0                                 0
#
#       spouse_compressed_Stevron Frey  spouse_compressed_Unknown  \
# S.No
# 959                                0                          1
# 9                                  0                          1
# 444                                0                          1
# 182                                0                          1
# 215                                0                          1
# ...                              ...                        ...
# 288                                0                          1
# 518                                0                          1
# 1258                               0                          1
# 646                                0                          1
# 599                                0                          1
#
#       spouse_compressed_Viserys I Targaryen  spouse_compressed_Walder Frey  \
# S.No
# 959                                       0                              0
# 9                                         0                              0
# 444                                       0                              0
# 182                                       0                              0
# 215                                       0                              0
# ...                                     ...                            ...
# 288                                       0                              0
# 518                                       0                              0
# 1258                                      0                              0
# 646                                       0                              0
# 599                                       0                              0
#
#       spouse_compressed_Yandry
# S.No
# 959                          0
# 9                            0
# 444                          0
# 182                          0
# 215                          0
# ...                        ...
# 288                          0
# 518                          0
# 1258                         0
# 646                          0
# 599                          0
#
# [1167 rows x 60 columns]

# %% [markdown]
# ## Часть 2. Обучение моделей

# %% [markdown]
# В данной части домашнего задания, мы хотим научиться обучать модели для задачи классификации на наших данных.

# %% [markdown]
# **Задание 2.1.**
#
#
# Вым можете работать с одно из предложенных моделей из библиотеки `sklearn`
# * LogisticRegression
# * RandomForestClassifier
# * AdaBoostClassifier
# * GaussianProcessClassifier
# * GaussianNB
# * KNeighborsClassifier
# * SVC
# * DecisionTreeClassifier

# %% [markdown]
# Однако в этом домашнем задании мы предлагаем выбрать и поработать с моделью `LogisticRegression`.

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Импортируйте остальные модели из библиотеки `sklearn`. Чтобы понять как это сделать, воспользуйтесь официальный документацией `sklearn` $→$ [тык](https://scikit-learn.org/dev/user_guide.html). По ключевому названию модели, вы сможете найти необходимую информацию о том, как можно импортировать модель из библиотеки.

# %% [markdown]
# **Задание 2.2.** Обучите модель и сделайте предсказание на тестовой выборке

# %% [markdown]
# В качестве примера, обучим модель `LogisticRegression` и сделаем на ней предсказания на тестовой выборке.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, Normalizer, FunctionTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

noop = FunctionTransformer()

# Пайплайн
pipe = Pipeline([
    ('preprocessing', noop),
    ('classifier', KNeighborsClassifier())
])


param_grid_simple = [
    {
        'preprocessing': [
            None,
            StandardScaler(),
            MinMaxScaler(),
            RobustScaler()
        ],
        'classifier': [
            LogisticRegression(random_state=42, max_iter=1000),
            RandomForestClassifier(random_state=42),
            AdaBoostClassifier(random_state=42),
            GaussianProcessClassifier(random_state=42, max_iter_predict=100),
            GaussianNB(),
            KNeighborsClassifier(),
            SVC(random_state=42),
            DecisionTreeClassifier(random_state=42)
        ]
    }
]


grid_search = GridSearchCV(
    pipe,
    param_grid_simple,
    cv=6,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train, y_train)


print("----------------- Обучили и тестировали -------------------")
print("Наилучшие параметры:\n{}\n".format(grid_search.best_params_))
print("Средняя правильность для наилучшей модели кроссвалидации на \
                валидационных тестовых наборах: {:.6f}\n".format(grid_search.best_score_))
gridresults = pd.DataFrame(grid_search.cv_results_)
display(gridresults.sort_values(["rank_test_score"]).T)
# Out:
# Fitting 6 folds for each of 32 candidates, totalling 192 fits
# ----------------- Обучили и тестировали -------------------
# Наилучшие параметры:
# {'classifier': RandomForestClassifier(random_state=42), 'preprocessing': StandardScaler()}
#
# Средняя правильность для наилучшей модели кроссвалидации на                 валидационных тестовых наборах: 0.827756
#                                                                     5   \
# mean_fit_time                                                 0.461947
# std_fit_time                                                  0.061332
# mean_score_time                                               0.029124
# std_score_time                                                0.010783
# param_classifier               RandomForestClassifier(random_state=42)
# param_preprocessing                                   StandardScaler()
# params               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                             0.846154
# split1_test_score                                             0.820513
# split2_test_score                                             0.825641
# split3_test_score                                             0.829897
# split4_test_score                                             0.835052
# split5_test_score                                             0.809278
# mean_test_score                                               0.827756
# std_test_score                                                0.011508
# rank_test_score                                                      1
#
#                                                                     7   \
# mean_fit_time                                                 1.292129
# std_fit_time                                                  0.277236
# mean_score_time                                               0.091171
# std_score_time                                                0.037914
# param_classifier               RandomForestClassifier(random_state=42)
# param_preprocessing                                     RobustScaler()
# params               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                             0.841026
# split1_test_score                                             0.815385
# split2_test_score                                             0.825641
# split3_test_score                                             0.829897
# split4_test_score                                             0.835052
# split5_test_score                                             0.809278
# mean_test_score                                               0.826046
# std_test_score                                                0.010919
# rank_test_score                                                      2
#
#                                                                     6   \
# mean_fit_time                                                 1.168457
# std_fit_time                                                  0.565871
# mean_score_time                                               0.078314
# std_score_time                                                0.028014
# param_classifier               RandomForestClassifier(random_state=42)
# param_preprocessing                                     MinMaxScaler()
# params               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                             0.835897
# split1_test_score                                             0.820513
# split2_test_score                                             0.825641
# split3_test_score                                             0.829897
# split4_test_score                                             0.829897
# split5_test_score                                             0.804124
# mean_test_score                                               0.824328
# std_test_score                                                0.010168
# rank_test_score                                                      3
#
#                                                                     4   \
# mean_fit_time                                                 0.430402
# std_fit_time                                                  0.016075
# mean_score_time                                               0.024565
# std_score_time                                                0.001314
# param_classifier               RandomForestClassifier(random_state=42)
# param_preprocessing                                               None
# params               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                             0.835897
# split1_test_score                                             0.820513
# split2_test_score                                             0.825641
# split3_test_score                                             0.829897
# split4_test_score                                             0.829897
# split5_test_score                                             0.804124
# mean_test_score                                               0.824328
# std_test_score                                                0.010168
# rank_test_score                                                      3
#
#                                                                     3   \
# mean_fit_time                                                 0.111958
# std_fit_time                                                  0.011427
# mean_score_time                                               0.006363
# std_score_time                                                0.000483
# param_classifier     LogisticRegression(max_iter=1000, random_state...
# param_preprocessing                                     RobustScaler()
# params               {'classifier': LogisticRegression(max_iter=100...
# split0_test_score                                              0.85641
# split1_test_score                                             0.794872
# split2_test_score                                             0.794872
# split3_test_score                                             0.824742
# split4_test_score                                             0.835052
# split5_test_score                                             0.824742
# mean_test_score                                               0.821782
# std_test_score                                                 0.02176
# rank_test_score                                                      5
#
#                                                                     1   \
# mean_fit_time                                                 0.023749
# std_fit_time                                                  0.002683
# mean_score_time                                               0.006848
# std_score_time                                                0.000946
# param_classifier     LogisticRegression(max_iter=1000, random_state...
# param_preprocessing                                   StandardScaler()
# params               {'classifier': LogisticRegression(max_iter=100...
# split0_test_score                                             0.851282
# split1_test_score                                             0.805128
# split2_test_score                                             0.794872
# split3_test_score                                             0.829897
# split4_test_score                                             0.814433
# split5_test_score                                             0.819588
# mean_test_score                                                 0.8192
# std_test_score                                                0.018057
# rank_test_score                                                      6
#
#                                                                     0   \
# mean_fit_time                                                 0.118028
# std_fit_time                                                  0.035679
# mean_score_time                                               0.006191
# std_score_time                                                0.000771
# param_classifier     LogisticRegression(max_iter=1000, random_state...
# param_preprocessing                                               None
# params               {'classifier': LogisticRegression(max_iter=100...
# split0_test_score                                             0.841026
# split1_test_score                                             0.794872
# split2_test_score                                             0.784615
# split3_test_score                                             0.819588
# split4_test_score                                             0.845361
# split5_test_score                                             0.809278
# mean_test_score                                                0.81579
# std_test_score                                                0.022277
# rank_test_score                                                      7
#
#                                                                     14  \
# mean_fit_time                                                 1.597931
# std_fit_time                                                  0.427971
# mean_score_time                                               0.042111
# std_score_time                                                0.013322
# param_classifier            GaussianProcessClassifier(random_state=42)
# param_preprocessing                                     MinMaxScaler()
# params               {'classifier': GaussianProcessClassifier(rando...
# split0_test_score                                             0.841026
# split1_test_score                                             0.794872
# split2_test_score                                                  0.8
# split3_test_score                                             0.814433
# split4_test_score                                             0.814433
# split5_test_score                                             0.829897
# mean_test_score                                               0.815777
# std_test_score                                                 0.01595
# rank_test_score                                                      8
#
#                                                                     26  \
# mean_fit_time                                                 0.077704
# std_fit_time                                                  0.002839
# mean_score_time                                               0.029787
# std_score_time                                                0.005879
# param_classifier                                  SVC(random_state=42)
# param_preprocessing                                     MinMaxScaler()
# params               {'classifier': SVC(random_state=42), 'preproce...
# split0_test_score                                             0.846154
# split1_test_score                                             0.789744
# split2_test_score                                             0.815385
# split3_test_score                                             0.809278
# split4_test_score                                             0.819588
# split5_test_score                                             0.814433
# mean_test_score                                               0.815764
# std_test_score                                                0.016629
# rank_test_score                                                      9
#
#                                                                     22  ...  \
# mean_fit_time                                                 0.011667  ...
# std_fit_time                                                  0.001334  ...
# mean_score_time                                               0.014848  ...
# std_score_time                                                0.006529  ...
# param_classifier                                KNeighborsClassifier()  ...
# param_preprocessing                                     MinMaxScaler()  ...
# params               {'classifier': KNeighborsClassifier(), 'prepro...  ...
# split0_test_score                                             0.835897  ...
# split1_test_score                                             0.820513  ...
# split2_test_score                                             0.789744  ...
# split3_test_score                                             0.778351  ...
# split4_test_score                                             0.845361  ...
# split5_test_score                                             0.819588  ...
# mean_test_score                                               0.814909  ...
# std_test_score                                                0.023773  ...
# rank_test_score                                                     10  ...
#
#                                                                     27  \
# mean_fit_time                                                 0.103924
# std_fit_time                                                  0.021778
# mean_score_time                                               0.025202
# std_score_time                                                0.004284
# param_classifier                                  SVC(random_state=42)
# param_preprocessing                                     RobustScaler()
# params               {'classifier': SVC(random_state=42), 'preproce...
# split0_test_score                                                  0.8
# split1_test_score                                             0.789744
# split2_test_score                                             0.779487
# split3_test_score                                              0.78866
# split4_test_score                                             0.793814
# split5_test_score                                             0.809278
# mean_test_score                                               0.793497
# std_test_score                                                0.009356
# rank_test_score                                                     23
#
#                                                                     24  \
# mean_fit_time                                                  0.07269
# std_fit_time                                                  0.002668
# mean_score_time                                               0.022476
# std_score_time                                                 0.00243
# param_classifier                                  SVC(random_state=42)
# param_preprocessing                                               None
# params               {'classifier': SVC(random_state=42), 'preproce...
# split0_test_score                                                  0.8
# split1_test_score                                             0.789744
# split2_test_score                                             0.774359
# split3_test_score                                              0.78866
# split4_test_score                                              0.78866
# split5_test_score                                             0.793814
# mean_test_score                                               0.789206
# std_test_score                                                0.007736
# rank_test_score                                                     24
#
#                                                                     29  \
# mean_fit_time                                                 0.020252
# std_fit_time                                                  0.000617
# mean_score_time                                               0.006504
# std_score_time                                                0.000852
# param_classifier               DecisionTreeClassifier(random_state=42)
# param_preprocessing                                   StandardScaler()
# params               {'classifier': DecisionTreeClassifier(random_s...
# split0_test_score                                             0.784615
# split1_test_score                                             0.784615
# split2_test_score                                             0.758974
# split3_test_score                                             0.778351
# split4_test_score                                             0.809278
# split5_test_score                                             0.747423
# mean_test_score                                               0.777209
# std_test_score                                                0.019829
# rank_test_score                                                     25
#
#                                                                     31  \
# mean_fit_time                                                 0.038206
# std_fit_time                                                  0.003926
# mean_score_time                                               0.005612
# std_score_time                                                 0.00108
# param_classifier               DecisionTreeClassifier(random_state=42)
# param_preprocessing                                     RobustScaler()
# params               {'classifier': DecisionTreeClassifier(random_s...
# split0_test_score                                             0.779487
# split1_test_score                                             0.779487
# split2_test_score                                             0.758974
# split3_test_score                                             0.778351
# split4_test_score                                             0.809278
# split5_test_score                                             0.747423
# mean_test_score                                                 0.7755
# std_test_score                                                0.019332
# rank_test_score                                                     26
#
#                                                                     28  \
# mean_fit_time                                                 0.015008
# std_fit_time                                                  0.000454
# mean_score_time                                               0.006027
# std_score_time                                                0.001017
# param_classifier               DecisionTreeClassifier(random_state=42)
# param_preprocessing                                               None
# params               {'classifier': DecisionTreeClassifier(random_s...
# split0_test_score                                             0.779487
# split1_test_score                                             0.779487
# split2_test_score                                             0.758974
# split3_test_score                                             0.778351
# split4_test_score                                             0.809278
# split5_test_score                                             0.742268
# mean_test_score                                               0.774641
# std_test_score                                                0.020631
# rank_test_score                                                     27
#
#                                                                     30  \
# mean_fit_time                                                  0.01949
# std_fit_time                                                  0.000412
# mean_score_time                                               0.006127
# std_score_time                                                0.000263
# param_classifier               DecisionTreeClassifier(random_state=42)
# param_preprocessing                                     MinMaxScaler()
# params               {'classifier': DecisionTreeClassifier(random_s...
# split0_test_score                                             0.779487
# split1_test_score                                             0.779487
# split2_test_score                                             0.758974
# split3_test_score                                             0.778351
# split4_test_score                                             0.809278
# split5_test_score                                             0.742268
# mean_test_score                                               0.774641
# std_test_score                                                0.020631
# rank_test_score                                                     27
#
#                                                                     16  \
# mean_fit_time                                                 0.008253
# std_fit_time                                                  0.001063
# mean_score_time                                               0.004674
# std_score_time                                                0.000373
# param_classifier                                          GaussianNB()
# param_preprocessing                                               None
# params               {'classifier': GaussianNB(), 'preprocessing': ...
# split0_test_score                                             0.266667
# split1_test_score                                             0.266667
# split2_test_score                                             0.246154
# split3_test_score                                             0.350515
# split4_test_score                                             0.278351
# split5_test_score                                             0.257732
# mean_test_score                                               0.277681
# std_test_score                                                0.034009
# rank_test_score                                                     29
#
#                                                                     19  \
# mean_fit_time                                                 0.030876
# std_fit_time                                                  0.002224
# mean_score_time                                               0.005629
# std_score_time                                                0.000202
# param_classifier                                          GaussianNB()
# param_preprocessing                                     RobustScaler()
# params               {'classifier': GaussianNB(), 'preprocessing': ...
# split0_test_score                                             0.266667
# split1_test_score                                             0.266667
# split2_test_score                                             0.246154
# split3_test_score                                             0.350515
# split4_test_score                                             0.278351
# split5_test_score                                             0.257732
# mean_test_score                                               0.277681
# std_test_score                                                0.034009
# rank_test_score                                                     29
#
#                                                                     18  \
# mean_fit_time                                                 0.012162
# std_fit_time                                                  0.002106
# mean_score_time                                               0.005487
# std_score_time                                                 0.00017
# param_classifier                                          GaussianNB()
# param_preprocessing                                     MinMaxScaler()
# params               {'classifier': GaussianNB(), 'preprocessing': ...
# split0_test_score                                             0.235897
# split1_test_score                                             0.246154
# split2_test_score                                             0.241026
# split3_test_score                                             0.314433
# split4_test_score                                             0.247423
# split5_test_score                                             0.247423
# mean_test_score                                               0.255393
# std_test_score                                                0.026723
# rank_test_score                                                     31
#
#                                                                     17
# mean_fit_time                                                 0.012678
# std_fit_time                                                  0.001576
# mean_score_time                                               0.005543
# std_score_time                                                0.000379
# param_classifier                                          GaussianNB()
# param_preprocessing                                   StandardScaler()
# params               {'classifier': GaussianNB(), 'preprocessing': ...
# split0_test_score                                             0.235897
# split1_test_score                                             0.246154
# split2_test_score                                             0.235897
# split3_test_score                                             0.304124
# split4_test_score                                             0.247423
# split5_test_score                                             0.242268
# mean_test_score                                               0.251961
# std_test_score                                                0.023753
# rank_test_score                                                     32
#
# [16 rows x 32 columns]

# %%
pipe_rf = Pipeline([
    ('preprocessing', StandardScaler()),
    ('classifier', RandomForestClassifier())
])

param_grid_rf = [
    {
        'preprocessing': [StandardScaler()],
        'classifier': [RandomForestClassifier(random_state=42)],
        'classifier__n_estimators': [50, 100, 200, 300],
        'classifier__max_depth': [None, 10, 20, 30, 50],
        'classifier__min_samples_split': [2, 5, 10]
    }
]

grid_rf = GridSearchCV(
    pipe_rf,
    param_grid_rf,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

grid_rf.fit(X_train, y_train)

gridresults = pd.DataFrame(grid_rf.cv_results_)
display(gridresults.sort_values(["rank_test_score"]).T)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
#                                                                                     42  \
# mean_fit_time                                                                 1.043204
# std_fit_time                                                                  0.216239
# mean_score_time                                                                0.05236
# std_score_time                                                                0.012605
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         30
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     200
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.84188
# split1_test_score                                                             0.854701
# split2_test_score                                                             0.806867
# split3_test_score                                                             0.849785
# split4_test_score                                                              0.83691
# mean_test_score                                                               0.838029
# std_test_score                                                                0.016753
# rank_test_score                                                                      1
#
#                                                                                     6   \
# mean_fit_time                                                                 0.743501
# std_fit_time                                                                  0.009816
# mean_score_time                                                               0.040972
# std_score_time                                                                0.001076
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                       None
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     200
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.84188
# split1_test_score                                                             0.854701
# split2_test_score                                                             0.806867
# split3_test_score                                                             0.841202
# split4_test_score                                                              0.83691
# mean_test_score                                                               0.836312
# std_test_score                                                                0.015877
# rank_test_score                                                                      2
#
#                                                                                     54  \
# mean_fit_time                                                                 0.815275
# std_fit_time                                                                  0.029479
# mean_score_time                                                               0.044385
# std_score_time                                                                0.002464
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         50
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     200
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.84188
# split1_test_score                                                             0.854701
# split2_test_score                                                             0.806867
# split3_test_score                                                             0.841202
# split4_test_score                                                              0.83691
# mean_test_score                                                               0.836312
# std_test_score                                                                0.015877
# rank_test_score                                                                      2
#
#                                                                                     5   \
# mean_fit_time                                                                 0.381148
# std_fit_time                                                                  0.014751
# mean_score_time                                                               0.024779
# std_score_time                                                                0.001531
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                       None
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     100
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.82906
# split1_test_score                                                             0.854701
# split2_test_score                                                             0.811159
# split3_test_score                                                             0.841202
# split4_test_score                                                             0.824034
# mean_test_score                                                               0.832031
# std_test_score                                                                0.014876
# rank_test_score                                                                      4
#
#                                                                                     41  \
# mean_fit_time                                                                 0.655158
# std_fit_time                                                                  0.127536
# mean_score_time                                                               0.047635
# std_score_time                                                                0.016177
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         30
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     100
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.82906
# split1_test_score                                                             0.854701
# split2_test_score                                                             0.811159
# split3_test_score                                                             0.841202
# split4_test_score                                                             0.824034
# mean_test_score                                                               0.832031
# std_test_score                                                                0.014876
# rank_test_score                                                                      4
#
#                                                                                     53  \
# mean_fit_time                                                                 0.386687
# std_fit_time                                                                  0.013736
# mean_score_time                                                                 0.0234
# std_score_time                                                                0.001427
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         50
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     100
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.82906
# split1_test_score                                                             0.854701
# split2_test_score                                                             0.811159
# split3_test_score                                                             0.841202
# split4_test_score                                                             0.824034
# mean_test_score                                                               0.832031
# std_test_score                                                                0.014876
# rank_test_score                                                                      4
#
#                                                                                     30  \
# mean_fit_time                                                                  0.78423
# std_fit_time                                                                  0.008708
# mean_score_time                                                               0.044688
# std_score_time                                                                0.005406
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         20
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     200
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.837607
# split1_test_score                                                             0.846154
# split2_test_score                                                             0.802575
# split3_test_score                                                             0.849785
# split4_test_score                                                             0.824034
# mean_test_score                                                               0.832031
# std_test_score                                                                0.017189
# rank_test_score                                                                      4
#
#                                                                                     27  \
# mean_fit_time                                                                 1.815049
# std_fit_time                                                                  0.287773
# mean_score_time                                                               0.074151
# std_score_time                                                                0.008681
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         20
# param_classifier__min_samples_split                                                  2
# param_classifier__n_estimators                                                     300
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.837607
# split1_test_score                                                             0.833333
# split2_test_score                                                             0.815451
# split3_test_score                                                             0.841202
# split4_test_score                                                             0.828326
# mean_test_score                                                               0.831184
# std_test_score                                                                0.008966
# rank_test_score                                                                      8
#
#                                                                                     31  \
# mean_fit_time                                                                 1.128809
# std_fit_time                                                                  0.018916
# mean_score_time                                                               0.060333
# std_score_time                                                                 0.00222
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         20
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     300
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.824786
# split1_test_score                                                             0.846154
# split2_test_score                                                             0.802575
# split3_test_score                                                             0.854077
# split4_test_score                                                             0.828326
# mean_test_score                                                               0.831184
# std_test_score                                                                0.017976
# rank_test_score                                                                      9
#
#                                                                                     24  \
# mean_fit_time                                                                 0.233908
# std_fit_time                                                                  0.021779
# mean_score_time                                                               0.017893
# std_score_time                                                                0.001625
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         20
# param_classifier__min_samples_split                                                  2
# param_classifier__n_estimators                                                      50
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.833333
# split1_test_score                                                              0.84188
# split2_test_score                                                             0.806867
# split3_test_score                                                             0.845494
# split4_test_score                                                             0.828326
# mean_test_score                                                                0.83118
# std_test_score                                                                0.013589
# rank_test_score                                                                     10
#
#                                      ...  \
# mean_fit_time                        ...
# std_fit_time                         ...
# mean_score_time                      ...
# std_score_time                       ...
# param_classifier                     ...
# param_classifier__max_depth          ...
# param_classifier__min_samples_split  ...
# param_classifier__n_estimators       ...
# param_preprocessing                  ...
# params                               ...
# split0_test_score                    ...
# split1_test_score                    ...
# split2_test_score                    ...
# split3_test_score                    ...
# split4_test_score                    ...
# mean_test_score                      ...
# std_test_score                       ...
# rank_test_score                      ...
#
#                                                                                     22  \
# mean_fit_time                                                                 0.687058
# std_fit_time                                                                  0.026832
# mean_score_time                                                               0.038495
# std_score_time                                                                0.001095
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                 10
# param_classifier__n_estimators                                                     200
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.833333
# split1_test_score                                                             0.820513
# split2_test_score                                                             0.806867
# split3_test_score                                                             0.832618
# split4_test_score                                                             0.811159
# mean_test_score                                                               0.820898
# std_test_score                                                                0.010806
# rank_test_score                                                                     51
#
#                                                                                     34  \
# mean_fit_time                                                                 1.070111
# std_fit_time                                                                  0.294482
# mean_score_time                                                               0.049078
# std_score_time                                                                0.015745
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         20
# param_classifier__min_samples_split                                                 10
# param_classifier__n_estimators                                                     200
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.820513
# split1_test_score                                                             0.837607
# split2_test_score                                                               0.7897
# split3_test_score                                                              0.83691
# split4_test_score                                                             0.819742
# mean_test_score                                                               0.820894
# std_test_score                                                                 0.01738
# rank_test_score                                                                     52
#
#                                                                                     17  \
# mean_fit_time                                                                 0.368078
# std_fit_time                                                                  0.011336
# mean_score_time                                                               0.029421
# std_score_time                                                                0.009793
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     100
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.833333
# split1_test_score                                                             0.824786
# split2_test_score                                                             0.806867
# split3_test_score                                                             0.824034
# split4_test_score                                                             0.815451
# mean_test_score                                                               0.820894
# std_test_score                                                                0.009013
# rank_test_score                                                                     53
#
#                                                                                     18  \
# mean_fit_time                                                                  0.73178
# std_fit_time                                                                  0.011822
# mean_score_time                                                               0.039712
# std_score_time                                                                0.000854
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                     200
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.833333
# split1_test_score                                                              0.82906
# split2_test_score                                                             0.806867
# split3_test_score                                                             0.824034
# split4_test_score                                                             0.811159
# mean_test_score                                                               0.820891
# std_test_score                                                                0.010226
# rank_test_score                                                                     54
#
#                                                                                     23  \
# mean_fit_time                                                                 1.104137
# std_fit_time                                                                  0.049535
# mean_score_time                                                               0.057789
# std_score_time                                                                 0.00369
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                 10
# param_classifier__n_estimators                                                     300
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.82906
# split1_test_score                                                             0.820513
# split2_test_score                                                             0.806867
# split3_test_score                                                             0.832618
# split4_test_score                                                             0.806867
# mean_test_score                                                               0.819185
# std_test_score                                                                  0.0108
# rank_test_score                                                                     55
#
#                                                                                     16  \
# mean_fit_time                                                                 0.186128
# std_fit_time                                                                  0.003627
# mean_score_time                                                               0.014856
# std_score_time                                                                0.000389
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                  5
# param_classifier__n_estimators                                                      50
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.833333
# split1_test_score                                                             0.820513
# split2_test_score                                                             0.793991
# split3_test_score                                                             0.832618
# split4_test_score                                                             0.815451
# mean_test_score                                                               0.819181
# std_test_score                                                                 0.01436
# rank_test_score                                                                     56
#
#                                                                                     13  \
# mean_fit_time                                                                 0.347125
# std_fit_time                                                                  0.011532
# mean_score_time                                                               0.022507
# std_score_time                                                                0.000988
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                  2
# param_classifier__n_estimators                                                     100
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.82906
# split1_test_score                                                              0.82906
# split2_test_score                                                               0.7897
# split3_test_score                                                             0.841202
# split4_test_score                                                             0.806867
# mean_test_score                                                               0.819178
# std_test_score                                                                0.018444
# rank_test_score                                                                     57
#
#                                                                                     20  \
# mean_fit_time                                                                 0.221113
# std_fit_time                                                                  0.029067
# mean_score_time                                                               0.016971
# std_score_time                                                                0.006095
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                 10
# param_classifier__n_estimators                                                      50
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.84188
# split1_test_score                                                             0.824786
# split2_test_score                                                             0.798283
# split3_test_score                                                             0.828326
# split4_test_score                                                             0.802575
# mean_test_score                                                                0.81917
# std_test_score                                                                0.016388
# rank_test_score                                                                     58
#
#                                                                                     21  \
# mean_fit_time                                                                 0.338933
# std_fit_time                                                                  0.009292
# mean_score_time                                                               0.022753
# std_score_time                                                                0.001889
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                 10
# param_classifier__n_estimators                                                     100
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                             0.837607
# split1_test_score                                                             0.820513
# split2_test_score                                                             0.798283
# split3_test_score                                                             0.828326
# split4_test_score                                                             0.802575
# mean_test_score                                                               0.817461
# std_test_score                                                                0.014984
# rank_test_score                                                                     59
#
#                                                                                     12
# mean_fit_time                                                                 0.547218
# std_fit_time                                                                  0.164533
# mean_score_time                                                               0.032433
# std_score_time                                                                 0.01261
# param_classifier                               RandomForestClassifier(random_state=42)
# param_classifier__max_depth                                                         10
# param_classifier__min_samples_split                                                  2
# param_classifier__n_estimators                                                      50
# param_preprocessing                                                   StandardScaler()
# params                               {'classifier': RandomForestClassifier(random_s...
# split0_test_score                                                              0.82906
# split1_test_score                                                             0.820513
# split2_test_score                                                             0.793991
# split3_test_score                                                             0.824034
# split4_test_score                                                             0.811159
# mean_test_score                                                               0.815751
# std_test_score                                                                0.012353
# rank_test_score                                                                     60
#
# [18 rows x 60 columns]

# %%
best_pipe = Pipeline([
    ('preprocessing', StandardScaler()),
    ('classifier', RandomForestClassifier(min_samples_split = 5,max_depth = 50,n_estimators = 200))
])

best_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing', StandardScaler()),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=50, min_samples_split=5,
#                                         n_estimators=200))])

# %% [markdown]
# ## Часть 3. Оцените качество моделей

# %% [markdown]
# Вам необходимо познакомиться с метриками задачи классификации из sklearn. Оцените все модели и выберите лучшую по метрике качества Accuracy.
#
# С метриками классификации вы можете ознакомиться в [Yandex ML Book](https://education.yandex.ru/handbook/ml/article/metriki-klassifikacii-i-regressii).
#
# Для простоты в данном домашнем задании мы будем работать с самой базовой метрикой для задачи классификации - accuracy.

# %% [markdown]
# **Задание 3.1.** Вам необходимо посчитать метрику для всех моделей и выбрать лучшую модель.

# %% [markdown]
# Сначала импортируем необходимую функцию из библиотеки sklearn для подсчета accuracy.

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# В качестве примера, посчитаем метрику accuracy для модели `LogisticRegression`

# %%
accuracy = accuracy_score(y_val, best_pipe.predict(X_val))
print("Accuracy : %.4f" % accuracy)
# Out:
# Accuracy : 0.8256

# %% [markdown]
# Возможно, вы решите вернуться на несколько шагов и попробовать другие варианты преобразования и подбора признаков в модель. **Выберите** лучшую модель.

# %% [markdown]
# ### Тестовый датасет

# %% [markdown]
# В самом начале нашего домашнего задания мы скачивали тестовый датасет. Загрузите его в Pandas DataFrame при помощи функции read_csv

# %%
df = pd.read_csv(r'/content/game_of_thrones_test.csv',index_col= 'S.No')

# %% [markdown]
# По аналогии с тем, как мы работали с обучающим датасетом, давайте посмотрим в тестовом датасете на статистики признаков с разными типами данных

# %%
#Подсказка
df.loc[df['age']<0] # Находим данные с ошибками в дате рождения и возрасте
# Out:
#         name title  male culture  dateOfBirth mother father heir  \
# S.No
# 1685  Doreah   NaN     0  Lysene     278279.0    NaN    NaN  NaN
# 1869  Rhaego   NaN     0     NaN     298299.0    NaN    NaN  NaN
#
#                 house spouse  ...  book5  isAliveMother  isAliveFather  \
# S.No                          ...
# 1685  House Targaryen    NaN  ...      1            NaN            NaN
# 1869  House Targaryen    NaN  ...      0            NaN            NaN
#
#       isAliveHeir  isAliveSpouse  isMarried  isNoble       age  \
# S.No
# 1685          NaN            NaN          0        0 -277980.0
# 1869          NaN            NaN          0        0 -298001.0
#
#       numDeadRelations  popularity
# S.No
# 1685                 0    0.110368
# 1869                 6    0.167224
#
# [2 rows x 24 columns]

# %%
#Вы можете аккуратно поправить тестовые данные, воспользовавшись, например следующим кодом:
df.loc[1685, 'dateOfBirth'] = 278
df.loc[1869, 'dateOfBirth'] = 299
# замены в строке 1685: dateOfBirth -> 278. и age -> 0.
# замены в строке 1869: dateOfBirth -> 299. и age -> 0.

# %%
df['log_pop'] = np.log10(df["popularity"]*M+1)
df['boolDeadRelations'] = (df['numDeadRelations'] > 0).astype(int)
df['age_value'] = df['age'].fillna(0)
df['age_no_data'] = [1 if np.isnan(x) else 0 for x in df['age']]
df['culture_grouped'] = df['culture'].str.lower().map(cultures_grouped_inverted)
df['culture_grouped'].fillna('culture_no_data',inplace= True)
df.drop(cols_to_drop, axis=1, inplace=True)
df['spouse'].fillna('Unknown', inplace=True)
df['isAliveSpouse'].fillna(-1, inplace=True)
df['has_title'] = df['title'].notna().astype(int)
df['culture'].fillna('Unknown', inplace=True)
df['house'].fillna('Unknown House', inplace=True)
df.drop(['title','dateOfBirth','age','name','culture'],inplace= True,axis = 1)
df['house_compressed'] = df['house'].apply(lambda x: x if x in top_houses else 'Other House')
df.drop('house', axis=1, inplace=True)
df['spouse_compressed'] = df['spouse'].apply(lambda x: x if x in top_spouses else 'Other Spouse')
df.drop('spouse', axis=1, inplace=True)

df_end = pd.get_dummies(df, drop_first=False,dtype=int)
# Out:
# /tmp/ipython-input-520413374.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['culture_grouped'].fillna('culture_no_data',inplace= True)
# /tmp/ipython-input-520413374.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['spouse'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-520413374.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['isAliveSpouse'].fillna(-1, inplace=True)
# /tmp/ipython-input-520413374.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['culture'].fillna('Unknown', inplace=True)
# /tmp/ipython-input-520413374.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['house'].fillna('Unknown House', inplace=True)

# %% [markdown]
# Преобразуйте признаки в тестовом датасете по тому же пайплайну, как вы преобразовывали обучающие данные. Примените вашу лучшую модель на тестовом датасете для получения прогноза целевой переменной `isAlive`

# %%
best_pipe.predict(df_end)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1928128377.py in <cell line: 0>()
# ----> 1 best_pipe.predict(df_end)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/pipeline.py in predict(self, X, **params)
#     785             if not _routing_enabled():
#     786                 for _, name, transform in self._iter(with_final=False):
# --> 787                     Xt = transform.transform(Xt)
#     788                 return self.steps[-1][1].predict(Xt, **params)
#     789
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/_data.py in transform(self, X, copy)
#    1060
#    1061         copy = copy if copy is not None else self.copy
# -> 1062         X = validate_data(
#    1063             self,
#    1064             X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in _check_feature_names(estimator, X, reset)
#    2775             message += "Feature names must be in the same order as they were in fit.\n"
#    2776
# -> 2777         raise ValueError(message)
#    2778
#    2779
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - house_compressed_House Brax
# - house_compressed_House Crakehall
# - house_compressed_House Waynwood
# - spouse_compressed_Alys Arryn
# - spouse_compressed_Amerei Frey
# - ...

# %%
df_end
# Out:
#       male  book1  book2  book3  book4  book5  isAliveSpouse  isMarried  \
# S.No
# 1558     0      0      0      0      0      1           -1.0          0
# 1559     0      0      1      1      1      1           -1.0          0
# 1560     0      0      0      1      1      0           -1.0          0
# 1561     1      1      1      1      1      1           -1.0          0
# 1562     1      1      1      1      1      1            1.0          1
# ...    ...    ...    ...    ...    ...    ...            ...        ...
# 1942     1      1      1      1      1      1           -1.0          0
# 1943     1      0      1      0      1      1           -1.0          0
# 1944     1      1      1      1      1      1           -1.0          0
# 1945     1      0      0      1      1      1           -1.0          0
# 1946     1      0      0      1      1      1            1.0          1
#
#       isNoble  numDeadRelations  ...  house_compressed_House Targaryen  \
# S.No                             ...
# 1558        0                 0  ...                                 0
# 1559        0                 0  ...                                 0
# 1560        0                 0  ...                                 0
# 1561        1                 0  ...                                 0
# 1562        0                 0  ...                                 0
# ...       ...               ...  ...                               ...
# 1942        0                 0  ...                                 0
# 1943        0                 0  ...                                 0
# 1944        0                 0  ...                                 0
# 1945        0                 0  ...                                 0
# 1946        1                 4  ...                                 0
#
#       house_compressed_House Tyrell  house_compressed_Night's Watch  \
# S.No
# 1558                              0                               0
# 1559                              0                               0
# 1560                              0                               0
# 1561                              0                               0
# 1562                              0                               0
# ...                             ...                             ...
# 1942                              0                               0
# 1943                              0                               0
# 1944                              0                               0
# 1945                              0                               0
# 1946                              0                               0
#
#       house_compressed_Other House  house_compressed_Stone Crows  \
# S.No
# 1558                             1                             0
# 1559                             1                             0
# 1560                             1                             0
# 1561                             1                             0
# 1562                             0                             0
# ...                            ...                           ...
# 1942                             0                             0
# 1943                             1                             0
# 1944                             0                             0
# 1945                             1                             0
# 1946                             0                             0
#
#       house_compressed_Unknown House  spouse_compressed_Other Spouse  \
# S.No
# 1558                               0                               0
# 1559                               0                               0
# 1560                               0                               0
# 1561                               0                               0
# 1562                               0                               1
# ...                              ...                             ...
# 1942                               0                               0
# 1943                               0                               0
# 1944                               1                               0
# 1945                               0                               0
# 1946                               0                               1
#
#       spouse_compressed_Rohanne Webber  spouse_compressed_Unknown  \
# S.No
# 1558                                 0                          1
# 1559                                 0                          1
# 1560                                 0                          1
# 1561                                 0                          1
# 1562                                 0                          0
# ...                                ...                        ...
# 1942                                 0                          1
# 1943                                 0                          1
# 1944                                 0                          1
# 1945                                 0                          1
# 1946                                 0                          0
#
#       spouse_compressed_Walder Frey
# S.No
# 1558                              0
# 1559                              0
# 1560                              0
# 1561                              0
# 1562                              0
# ...                             ...
# 1942                              0
# 1943                              0
# 1944                              0
# 1945                              0
# 1946                              0
#
# [389 rows x 50 columns]

# %% [markdown]
# ### Файл `submission.csv`

# %% [markdown]
# Вам нужно вместо значений в `submission.csv` файле в колонке `isAlive`, подставить свои предсказания и сохранить измененный файл.

# %%
# !gdown 1M14conWjAW2QLoyCXbHEAy8bql2f99eF
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1M14conWjAW2QLoyCXbHEAy8bql2f99eF
# To: /content/submission.csv
# 100% 2.74k/2.74k [00:00<00:00, 8.69MB/s]

# %%
pd.read_csv(r"/content/game_of_thrones_test.csv")

# %%
submission = pd.read_csv("/content/submission.csv", index_col='S.No')

# %%
submission

# %% [markdown]
# Как сохранить измененный Pandas DataFrame в csv файл:

# %%
submission.to_csv("/content/new_submission.csv", index=False)
